# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("dataset_sdn.csv")

# %%
data[data['label'] == 1].head()
# Out:
#        dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 91  11335       1  10.0.0.1  10.0.0.8      4777    5092282   10  711000000
# 92  11335       1  10.0.0.1  10.0.0.8      4777    5092282   10  711000000
# 93  11335       1  10.0.0.1  10.0.0.8      4777    5092282   10  711000000
# 94  11335       1  10.0.0.1  10.0.0.8      4777    5092282   10  711000000
# 95  11335       1  10.0.0.1  10.0.0.8      4777    5092282   10  711000000
#
#          tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no  tx_bytes  \
# 91  1.071100e+10      3  ...        0         0       UDP        2      3753
# 92  1.071100e+10      3  ...        0         0       UDP        3      3679
# 93  1.071100e+10      3  ...        0         0       UDP        2      3733
# 94  1.071100e+10      3  ...        0         0       UDP        4  58460931
# 95  1.071100e+10      3  ...        0         0       UDP        3      3413
#
#     rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# ...

# %%
data[data['label'] == 0].head()
# Out:
#       dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 0  11425       1  10.0.0.1  10.0.0.8     45304   48294064  100  716000000
# 1  11605       1  10.0.0.1  10.0.0.8    126395  134737070  280  734000000
# 2  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 3  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 4  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
#
#         tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no   tx_bytes  \
# 0  1.010000e+11      3  ...      451         0       UDP        3  143928631
# 1  2.810000e+11      2  ...      451         0       UDP        4       3842
# 2  2.010000e+11      3  ...      451         0       UDP        1       3795
# 3  2.010000e+11      3  ...      451         0       UDP        2       3688
# 4  2.010000e+11      3  ...      451         0       UDP        3       3413
#
#   rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# ...

# %%
data = data.dropna()

# %%
columns = []
for i in data.columns:
    #print(data[i].dtype == 'O')
    if data[i].dtype != 'O':
        columns.append(i)
print(columns)
# Out:
# ['dt', 'switch', 'pktcount', 'bytecount', 'dur', 'dur_nsec', 'tot_dur', 'flows', 'packetins', 'pktperflow', 'byteperflow', 'pktrate', 'Pairflow', 'port_no', 'tx_bytes', 'rx_bytes', 'tx_kbps', 'rx_kbps', 'tot_kbps', 'label']

# %%
data = data[columns]

# %%
label = data["label"]
data = data.drop(["label"], axis=1)

# %%
# plt.figure(figsize=(15,8))
# ax = sns.heatmap(data.corr(), annot=True);

# %%
data.corr()[(data.corr() > 0.70) == True];

# %%
data.corr().columns.shape;

# %%
accepted_cols = ['pktcount', 'bytecount','tot_dur', 'packetins', 'pktperflow', 'byteperflow', 'pktrate', 'Pairflow','tx_bytes', 'rx_bytes', 'tx_kbps', 'rx_kbps', 'tot_kbps']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import BernoulliRBM

# %%
train_X, test_X, train_y, test_y = train_test_split(data[accepted_cols], label, test_size=0.30)

# %%
models = [LogisticRegression, SGDClassifier, MLPClassifier, BernoulliRBM]

# %%
model = LogisticRegression(max_iter=2000)

# %%
model.fit(train_X, train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=2000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(train_X, train_y)
# Out:
# 0.6107419483539009

# %%
model.score(test_X, test_y)
# Out:
# 0.608949666153056

# %%
for model in models:
    model_name = model.__name__
    model = model(max_iter=500)
    model.fit(train_X, train_y)
    print("Model Name:" + model_name)
    print("Train Score:" + str(model.score(train_X, train_y)))
    print("Test Score: " + str(model.score(test_X, test_y)))
# Out:
# Model Name:LogisticRegression
# Train Score:0.6107419483539009
# Test Score: 0.608949666153056
# Model Name:SGDClassifier
# Train Score:0.6110033431012423
# Test Score: 0.6089817668207499
